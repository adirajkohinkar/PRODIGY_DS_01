# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import os

# %%
df=pd.read_csv("ab36b185-bbba-406a-976e-e3e032da6d67_Data.csv")

# %%
df
# Out:
#                                           Series Name  Series Code  \
# 0                                   Population, total  SP.POP.TOTL
# 1                                   Population, total  SP.POP.TOTL
# 2                                   Population, total  SP.POP.TOTL
# 3                                   Population, total  SP.POP.TOTL
# 4                                   Population, total  SP.POP.TOTL
# ..                                                ...          ...
# 266                                               NaN          NaN
# 267                                               NaN          NaN
# 268                                               NaN          NaN
# 269  Data from database: World Development Indicators          NaN
# 270                          Last Updated: 02/21/2024          NaN
#
#        Country Name Country Code      1990      2000      2013      2014  \
# 0       Afghanistan          AFG  10694796  19542982  31541209  32716210
# ...

# %%
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code      1990  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  10694796
# 1  Population, total  SP.POP.TOTL         Albania          ALB   3286542
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  25518074
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     47818
# 4  Population, total  SP.POP.TOTL         Andorra          AND     53569
#
#        2000      2013      2014      2015      2016      2017      2018  \
# 0  19542982  31541209  32716210  33753499  34636207  35643418  36686784
# 1   3089027   2895092   2889104   2880703   2876101   2873457   2866376
# 2  30774621  38000626  38760168  39543154  40339329  41136546  41927007
# 3     58230     52995     52217     51368     50448     49463     48424
# 4     66097     71367     71621     71746     72540     73837     75013
#
#        2019      2020      2021      2022
# 0  37769499  38972230  40099462  41128771
# ...

# %%
df_final=df.drop(['Series Code','Country Code','Series Name'] ,axis=1)

# %%
chosen_country = 'Algeria'
country_data = df_final[df_final['Country Name'] == chosen_country]

# %%
years = country_data.columns[2:]
population = country_data.iloc[:, 2:].values.flatten()

plt.figure(figsize=(8,8))
plt.bar(years, population, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {chosen_country} Over the Years')


plt.show()

# %%
plt.hist(population, bins=10, color='skyblue', edgecolor='black')
plt.show()
